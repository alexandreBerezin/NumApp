# %%
# %load_ext autoreload
# %autoreload 2


import matplotlib.pyplot as plt
import numpy as np
import FeaturesExtractor.main as fe


plt.rcParams['figure.figsize'] = [10, 5]
plt.rcParams['figure.dpi'] = 120


param = {"chemin":"data/19_Droit.jpg",
         "longeur caractéristique du RBF":7,
         "nombre de points d'interêts":100,
        }

[img,coordPI] = fe.getFeatures(param)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# K : occurence trouvée dans la base de donnée

# %%
plt.imshow(img)
plt.scatter(coordPI[:,0],coordPI[:,1],color='r',s=5)

plt.show()

# %%
### Comparaison pour un même coin

param["chemin"] = "data/18379 Droit.jpg"
[img1,feature1] = fe.getFeatures(param)

param["chemin"] = "data/38324 Droit.jpg"
[img2,feature2] = fe.getFeatures(param)
# Out:
# K : occurence trouvée dans la base de donnée
# K : occurence trouvée dans la base de donnée

# %%
plt.subplot(1,2,1)
plt.imshow(img1)
plt.scatter(feature1[:,0],feature1[:,1],color="r",s=5)

plt.subplot(1,2,2)
plt.imshow(img2)
plt.scatter(feature2[:,0],feature2[:,1],color="r",s=5)

# %%
param["chemin"] = "data/6034 Droit.jpg"
[img3,feature3] = fe.getFeatures(param)

param["chemin"] = "data/12768 Droit.jpg"
[img4,feature4] = fe.getFeatures(param)
# Out:
# K : occurence trouvée dans la base de donnée
# K : occurence trouvée dans la base de donnée

# %%
plt.subplot(1,2,1)
plt.imshow(img3)
plt.scatter(feature3[:,0],feature3[:,1],color="r",s=5)

plt.subplot(1,2,2)
plt.imshow(img4)
plt.scatter(feature4[:,0],feature4[:,1],color="r",s=5)

# %% [markdown]
# ## amélioration ?
#
# - filtre couleur pour la rouille
# - modifier le filtre sobolev ? Laplace ?
